# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate
from collections import Counter

# %%
#read acc_right values
dar2 = pd.read_csv('E:/Keylogs/Typing_Participants/Participant_10_20171130/acc_right/ar2.csv',header=None)
dar3 = pd.read_csv('E:/Keylogs/Typing_Participants/Participant_10_20171130/acc_right/ar3.csv',header=None)
dar = pd.concat([dar2,dar3])

#read gyro_right values
dgr2 = pd.read_csv('E:/Keylogs/Typing_Participants/Participant_10_20171130/gyro_right/gr2.csv',header=None)
dgr3 = pd.read_csv('E:/Keylogs/Typing_Participants/Participant_10_20171130/gyro_right/gr3.csv',header=None)
dgr = pd.concat([dgr2,dgr3])

#read seq_num values
dsr2 = pd.read_csv('E:/Keylogs/Typing_Participants/Participant_10_20171130/seq_right/sr2.csv',header=None)
dsr3 = pd.read_csv('E:/Keylogs/Typing_Participants/Participant_10_20171130/seq_right/sr3.csv',header=None)
dsr = pd.concat([dsr2,dsr3])

# %%
dar = pd.read_csv('E:/Keylogs/Typing_Participants/Extracted/00ab666c-afb8-476e-9872-6472b4e66b68/20171030/accr.csv',header=None)
dgr = pd.read_csv('E:/Keylogs/Typing_Participants/Extracted/00ab666c-afb8-476e-9872-6472b4e66b68/20171030/gyrr.csv',header=None)
dsr = pd.read_csv('E:/Keylogs/Typing_Participants/Extracted/00ab666c-afb8-476e-9872-6472b4e66b68/20171030/seqr.csv',header=None)

# %%
def small_correction(dar,dgr,dsr):
    max_val = np.amax((dar.values[0,0], dgr.values[0,0]))
    dar = dar.values[dar.values[:,0] >= max_val,:]
    dgr = dgr.values[dgr.values[:,0] >= max_val,:]
    dsr = dsr.values[dsr.values[:,0] >= max_val,:]
    n_samples = dgr.shape[0]
    dar = dar[:n_samples,:]
    print(dar.shape)
    print(dsr.shape)
    print(dgr.shape)
    dar = pd.DataFrame(dar)
    dgr = pd.DataFrame(dgr)
    dsr = pd.DataFrame(dsr)
    return dar, dgr, dsr

# %%
print(dar.shape)
print(dsr.shape)
print(dgr.shape)
# Out:
# (794373, 5)
# (794373, 3)
# (794373, 5)

# %%
dar, dgr, dsr = small_correction(dar, dgr, dsr)
# Out:
# (99747, 5)
# (99747, 3)
# (99747, 5)

# %%
dr = pd.concat([dar[[0,2,3,4]], dgr[dgr.columns[2:5]], dsr[[2]]],axis = 1)
dr.columns = ['time' ,'arx', 'ary', 'arz', 'grx', 'gry', 'grz', 'sn']
dr
# Out:
#                 time       arx       ary       arz       grx       gry  \
# 0       1.509387e+12 -0.263062 -0.121521  0.418518 -1.052856 -0.312805
# 1       1.509387e+12 -0.263123 -0.121765  0.419128 -1.060486 -0.305176
# 2       1.509387e+12 -0.263489 -0.122070  0.419617 -1.068115 -0.297546
# 3       1.509387e+12 -0.263123 -0.121582  0.419922 -1.052856 -0.305176
# 4       1.509387e+12 -0.262695 -0.121826  0.418762 -1.022339 -0.267029
# 5       1.509387e+12 -0.262817 -0.122009  0.419434 -1.045227 -0.289917
# 6       1.509387e+12 -0.263184 -0.121704  0.419678 -1.060486 -0.289917
# 7       1.509387e+12 -0.263306 -0.122253  0.419006 -1.060486 -0.305176
# 8       1.509387e+12 -0.262939 -0.121521  0.418701 -1.068115 -0.312805
# 9       1.509387e+12 -0.263489 -0.122437  0.419373 -1.091003 -0.297546
# 10      1.509387e+12 -0.263489 -0.121643  0.418945 -1.083374 -0.305176
# 11      1.509387e+12 -0.263000 -0.121521  0.419006 -1.060486 -0.312805
# ...

# %%
#read acc_left values
dal2 = pd.read_csv('E:/Keylogs/Typing_Participants/Participant_10_20171130/acc_left/al2.csv',header=None)
dal3 = pd.read_csv('E:/Keylogs/Typing_Participants/Participant_10_20171130/acc_left/al3.csv',header=None)
dal = pd.concat([dal2,dal3])
#read gyro_left values
dgl2 = pd.read_csv('E:/Keylogs/Typing_Participants/Participant_10_20171130/gyro_left/gl2.csv',header=None)
dgl3 = pd.read_csv('E:/Keylogs/Typing_Participants/Participant_10_20171130/gyro_left/gl3.csv',header=None)
dgl = pd.concat([dgl2,dgl3])
#read seq_num values
dsl2 = pd.read_csv('E:/Keylogs/Typing_Participants/Participant_10_20171130/seq_left/sl2.csv',header=None)
dsl3 = pd.read_csv('E:/Keylogs/Typing_Participants/Participant_10_20171130/seq_left/sl3.csv',header=None)
dsl = pd.concat([dsl2,dsl3])

# %%
dal = pd.read_csv('E:/Keylogs/Typing_Participants/Extracted/00ab666c-afb8-476e-9872-6472b4e66b68/20171030/accl.csv',header=None)
dgl = pd.read_csv('E:/Keylogs/Typing_Participants/Extracted/00ab666c-afb8-476e-9872-6472b4e66b68/20171030/gyrl.csv',header=None)
dsl = pd.read_csv('E:/Keylogs/Typing_Participants/Extracted/00ab666c-afb8-476e-9872-6472b4e66b68/20171030/seql.csv',header=None)

# %%
print(dal.shape)
print(dsl.shape)
print(dgl.shape)
# Out:
# (728562, 5)
# (728562, 3)
# (728562, 5)

# %%
dal, dgl, dsl = small_correction(dal, dgl, dsl)
# Out:
# (174138, 5)
# (174138, 3)
# (174138, 5)

# %%
dl = pd.concat([dal[[0,2,3,4]], dgl[dgl.columns[2:5]], dsl[[2]]],axis = 1)
dl.columns = ['time' ,'alx', 'aly', 'alz', 'glx', 'gly', 'glz', 'sn']
dl
# Out:
#                 time       alx       aly       alz       glx       gly  \
# 0       1.509387e+12 -0.445129  0.171997  0.148071 -1.136780 -0.053406
# 1       1.509387e+12 -0.445068  0.171326  0.147583 -1.129150 -0.038147
# 2       1.509387e+12 -0.445374  0.172363  0.148193 -1.129150 -0.061035
# 3       1.509387e+12 -0.445374  0.171936  0.147339 -1.106262 -0.045776
# 4       1.509387e+12 -0.445129  0.171387  0.146362 -1.098633 -0.045776
# 5       1.509387e+12 -0.445007  0.171509  0.147583 -1.106262 -0.045776
# 6       1.509387e+12 -0.444519  0.171936  0.148499 -1.121521 -0.038147
# 7       1.509387e+12 -0.445129  0.171631  0.148254 -1.129150 -0.030518
# 8       1.509387e+12 -0.445129  0.171448  0.148621 -1.106262 -0.038147
# 9       1.509387e+12 -0.444885  0.171509  0.147705 -1.091003 -0.061035
# 10      1.509387e+12 -0.445068  0.171692  0.147583 -1.113892 -0.038147
# 11      1.509387e+12 -0.444458  0.171814  0.148315 -1.091003 -0.053406
# ...

# %%
# %matplotlib notebook

# %%
def preprocess_data(df):
    # Plot to visualize missing values
    l = len(df)
    plt.figure()
    plt.plot(df.values[:,0],np.ones((l,1)),'r.', ms=0.1)
    plt.show()
    
    thresh = 5000
    
    flag = np.diff(df.values[:,0])
    points = np.where(flag > thresh)
    Counter(flag)
    
    points=np.append(points[0],l-1) #Appending the last value
    print(points)
    
    prev = 0
    delta = 40
    new_t = []
    for point in points:
        time_diff = 40
        s_time = df['time'].iloc[prev]
        new_t.append((s_time))
        for i in range(prev,point):
            seq_diff = df['sn'].iloc[i+1] - df['sn'].iloc[i]
            if (seq_diff<0):
                seq_diff = 1024+ seq_diff
            s_time = s_time + seq_diff*40 
            new_t.append((s_time))

        prev = point+1
    new_t = np.array( new_t )
    constant_t = (np.arange(new_t[0], new_t[-1] , delta))
    
    f = interpolate.interp1d(new_t, df[df.columns[1:7]], axis =0)
    df_new = f(constant_t)
    print(df_new.shape)
    
    plt.figure()
    plt.plot(constant_t, df_new[:,2])
    plt.show()
    
    missing_data = np.zeros((len(constant_t),1))
    points = np.where(flag > thresh)
    for point in points[0]:
        missing_data[np.where((constant_t> df['time'].iloc[point]) & (constant_t<df['time'].iloc[point+1]))] = 1
    #plt.figure()
    plt.plot(constant_t, missing_data)
    plt.show()
    
    return constant_t, df_new, missing_data

# %%
time_l, dl_new,missing_l = preprocess_data(dl)
time_r, dr_new,missing_r = preprocess_data(dr)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [  7121  52189 146524 201925 245379 360725 403976 453554 500045 512213
#  552338 554828 560792 561115 561249 563047 565702 566379 569782 571052
#  571172 580224 580520 580695 592443 594232 616947 640344 640657 641853
#  641971 647739 661899 664522 665017 670207 675663 679387 692507 692687
#  693948 694016 694361 694377 694449 696107 697663 701968 705971 714675
#  714728 714759 714869 716577 719964 720488 722757 723251 723293 724694
#  725427 726022 727360 728561]
# (875643, 6)
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# [  7471  52513 146705 202229 246933 363584 408105 459525 504492 515259
#  559580 561938 569470 573682 576975 579400 582266 582739 591753 591980
#  592830 592853 593015 593055 593434 599119 600003 600033 600035 600062
#  600109 600260 622076 658679 665359 668917 672626 672798 699500 722036
# ...

# %%
print(time_r.shape)
print(time_l.shape)
# Out:
# (873999,)
# (875643,)

# %%
#Synchronizing left and right sensor values
max_val = np.amax((time_r[0], time_l[0]))
print(max_val)
dl_new = dl_new[time_l>=max_val,:]
dr_new = dr_new[time_r>=max_val,:]
missing_l = missing_l[time_l>=max_val]
missing_r = missing_r[time_r>=max_val]
time_l = time_l[time_l>=max_val] 
time_r = time_r[time_r>=max_val] 

n_values = np.abs(time_l.shape[0] - time_r.shape[0])
d = dr_new.shape[1]

missing_r = missing_r.reshape((-1,1))
missing_l = missing_l.reshape((-1,1))

if time_l.shape[0] > time_r.shape[0]:
    time_r = np.append(time_r, np.zeros((n_values,)))
    dr_new = np.append(dr_new, np.zeros((n_values, d)), axis=0)
    time_r = time_r.reshape((-1, 1))
    time_l = time_l.reshape((-1, 1))
    dataset = pd.DataFrame(np.concatenate((time_l, dl_new, dr_new, missing_l, missing_r), axis = 1))


elif time_l.shape[0] < time_r.shape[0]:
    time_l = np.append(time_l, np.zeros((n_values,)))
    dl_new = np.append(dl_new, np.zeros((n_values, d)), axis=0)
    time_r = time_r.reshape((-1, 1))
    time_l = time_l.reshape((-1, 1))
    dataset = pd.DataFrame(np.concatenate((time_r, dl_new, dr_new, missing_l, missing_r), axis = 1))


#Printing
print(time_r.shape)
print(time_l.shape)
print(dr_new.shape)
print(dl_new.shape)
print(missing_r.shape)
print(missing_l.shape)
# Out:
# 1.51205759892e+12
# (180020, 1)
# (180020, 1)
# (180020, 6)
# (180020, 6)
# (180020, 1)
# (180020, 1)

# %%
dataset = pd.DataFrame(np.concatenate((time_l, dl_new, dr_new, missing_l, missing_r), axis = 1))
dataset.columns = ['time' ,'arx', 'ary', 'arz', 'grx', 'gry', 'grz', 
                   'alx', 'aly', 'alz', 'glx', 'gly', 'glz',
                  'missing_l', 'missing_r']
print(dataset)
# Out:
#                 time       arx       ary       arz        grx        gry  \
# 0       1.512058e+12 -0.522339 -0.637451  0.528564 -11.978149  -8.193970
# 1       1.512058e+12 -0.513184 -0.647461  0.530762  -9.490967  -7.202148
# 2       1.512058e+12 -0.515747 -0.651611  0.543701  -6.317139  -5.615234
# 3       1.512058e+12 -0.513306 -0.655640  0.543091  -4.119873  -5.310059
# 4       1.512058e+12 -0.504883 -0.651001  0.532227  -1.037598  -4.470825
# 5       1.512058e+12 -0.506592 -0.655396  0.536011   2.716064  -3.311157
# 6       1.512058e+12 -0.505615 -0.669067  0.540649   3.463745  -2.883911
# 7       1.512058e+12 -0.500366 -0.665649  0.536743   5.859375  -2.319336
# 8       1.512058e+12 -0.490112 -0.640503  0.531616  11.062622  -1.724243
# 9       1.512058e+12 -0.492188 -0.650024  0.556152  12.817383  -1.754761
# 10      1.512058e+12 -0.485229 -0.674927  0.570801  10.696411  -3.677368
# 11      1.512058e+12 -0.486328 -0.669312  0.551880  12.741089  -5.905151
# ...

# %%
#Save Dataset
dataset.to_pickle('Participant_10.pkl')
